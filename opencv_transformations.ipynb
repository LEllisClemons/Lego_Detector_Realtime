# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('C:\\Users\elliscll\Documents\Lego_Project\\archive\dataset\\2357 brick corner 1x2x2 000L.png')
plt.imshow(img)

# %%
from src.Save_Edges import find_edges

gray_img, img_blur, edge_img=  find_edges(img)

#Finding Edge Detection requires looking at changes in pixel intensity
#To focus on the pixel intensity, we first convert to grayscale
plt.imshow(gray_img, cmap = 'gray')

# %%
#reduces noise in the image which can improve the edge detection results
plt.imshow(img_blur, cmap='gray')

# %%
#Edges found!
plt.imshow(edge_img, cmap='gray')
